# %%
# !mkdir images

# %%
# %cd /content/images
# Out:
# /content/images

# %%
import cv2

# %%
path = '/content/hazy.mp4'

# %%
#getting frames out of the dehazed video into the images folder
vidcap = cv2.VideoCapture(path)
def getFrame(sec):
    vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = vidcap.read()
    if hasFrames:
        cv2.imwrite("image"+str(count)+".png", image)
    return hasFrames
sec = 0
frameRate = 1
count=1
success = getFrame(sec)
while success:
    count = count + 1
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

# %%
 #cloning the dehazenet model
# !git clone https://github.com/proteus1991/GridDehazeNet.git
# Out:
# Cloning into 'GridDehazeNet'...
# remote: Enumerating objects: 2672, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 2672 (delta 0), reused 1 (delta 0), pack-reused 2669
# Receiving objects: 100% (2672/2672), 821.26 MiB | 37.44 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Checking out files: 100% (2586/2586), done.

# %%
# %cd /content/images
# Out:
# /content

# %%
# %cd /content/GridDehazeNet
# Out:
# /content/GridDehazeNet

# %%
# !rm /content/GridDehazeNet/data/test/SOTS/outdoor/clear/*
# !rm /content/GridDehazeNet/data/test/SOTS/outdoor/hazy/*
# Out:
# rm: cannot remove '/content/GridDehazeNet/data/test/SOTS/outdoor/clear/*': No such file or directory
# rm: cannot remove '/content/GridDehazeNet/data/test/SOTS/outdoor/hazy/*': No such file or directory

# %%
#copying all input hazy images to the model folder
cp -r /content/images/* /content/GridDehazeNet/data/test/SOTS/outdoor/hazy

# %%
p = /content/GridDehazeNet/data/test/SOTS/outdoor/hazy

# %%
#printing all the names of the hazy image files in the val_list.txt file 
#the model reads the file name from this file and then searches in the
#hazy image folder 
import os
f = open("/content/GridDehazeNet/data/test/SOTS/outdoor/val_list.txt","w")
directory = os.fsencode("/content/GridDehazeNet/data/test/SOTS/outdoor/hazy")
    
for files in os.listdir(directory):
     filename = os.fsdecode(files)
     f.write(filename + "\n")

# %%
cp -r /content/GridDehazeNet/data/test/SOTS/outdoor/hazy/* /content/GridDehazeNet/data/test/SOTS/outdoor/clear

# %%
#testing the model
! python3 test.py -category outdoor
# Out:
# --- Hyper-parameters for testing ---
# val_batch_size: 1
# network_height: 3
# network_width: 6
# num_dense_layer: 4
# growth_rate: 16
# lambda_loss: 0.04
# category: outdoor
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 24 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# --- Testing starts! ---
# /content/GridDehazeNet/utils.py:34: UserWarning: DEPRECATED: skimage.measure.compare_ssim has been moved to skimage.metrics.structural_similarity. It will be removed from skimage.measure in version 0.18.
# ...

# %%
from google.colab import files

# %%
# !zip -r /content/result.zip /content/GridDehazeNet/outdoor_results
# Out:
#   adding: content/GridDehazeNet/outdoor_results/ (stored 0%)
#   adding: content/GridDehazeNet/outdoor_results/0135_0.95_0.12.png (deflated 0%)
#   adding: content/GridDehazeNet/outdoor_results/0101_0.9_0.08.png (deflated 0%)
#   adding: content/GridDehazeNet/outdoor_results/0369_0.85_0.2.png (deflated 0%)
#   adding: content/GridDehazeNet/outdoor_results/1903_0.95_0.08.png (deflated 0%)
#   adding: content/GridDehazeNet/outdoor_results/0219_0.85_0.08.png (deflated 0%)
#   adding: content/GridDehazeNet/outdoor_results/0292_1_0.16.png (deflated 0%)
#   adding: content/GridDehazeNet/outdoor_results/0249_1_0.12.png (deflated 0%)
#   adding: content/GridDehazeNet/outdoor_results/0320_1_0.16.png (deflated 0%)
#   adding: content/GridDehazeNet/outdoor_results/0029_0.85_0.08.png (deflated 0%)
#   adding: content/GridDehazeNet/outdoor_results/image45.png (deflated 0%)
#   adding: content/GridDehazeNet/outdoor_results/0106_0.9_0.08.png (deflated 0%)
# ...

# %%
# !zip -r /content/res.zip /content/images
# Out:
#   adding: content/images/ (stored 0%)
#   adding: content/images/image45.png (deflated 15%)
#   adding: content/images/image51.png (deflated 20%)
#   adding: content/images/image49.png (deflated 17%)
#   adding: content/images/image9.png (deflated 18%)
#   adding: content/images/image35.png (deflated 16%)
#   adding: content/images/image30.png (deflated 16%)
#   adding: content/images/image19.png (deflated 18%)
#   adding: content/images/image55.png (deflated 17%)
#   adding: content/images/image29.png (deflated 17%)
#   adding: content/images/image46.png (deflated 20%)
#   adding: content/images/image23.png (deflated 14%)
#   adding: content/images/image57.png (deflated 18%)
#   adding: content/images/image10.png (deflated 17%)
#   adding: content/images/image11.png (deflated 20%)
#   adding: content/images/image28.png (deflated 15%)
#   adding: content/images/image44.png (deflated 18%)
#   adding: content/images/image6.png (deflated 19%)
# ...
